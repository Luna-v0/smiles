# %%
from yacc import validateSMILES
import pandas as pd
from rdkit import Chem
# Out:
# WARNING: 19 shift/reduce conflicts
# WARNING: 15 reduce/reduce conflicts
# True

# %%
file_path = 'data/mutagenicity.csv'

# %%
df = pd.read_csv(file_path, index_col=0)
df
# Out:
#       mut                                             smiles
# 0     1.0      COc1ccc(-c2nc(-c3ccccc3)c(-c3ccccc3)[nH]2)cc1
# 1     1.0                              Cc1c(N=C=O)cccc1N=C=O
# 2     0.0           CC1(Cn2ccnn2)C(C(=O)O)N2C(=O)CC2S1(=O)=O
# 3     0.0                                   C=CC(=O)OCCN(C)C
# 4     0.0                               Clc1cc(Cl)c(Cl)cc1Cl
# ...   ...                                                ...
# 4332  1.0  CCCn1cc2c3c(cccc31)C1C=C(C)CN(C)C1C2.O=C(O)C(O...
# 4333  0.0                 CCCCCCCCCCCCOCCOCCOCCOCCOCCOCCOCCO
# 4334  0.0                    Nc1ccn(C2C=C(CO)C(O)C2O)c(=O)n1
# 4335  1.0                                         CCC(C)ON=O
# 4336  0.0                   O=C1NC(=S)NC(=O)C1C(=O)Nc1ccccc1
#
# [4337 rows x 2 columns]

# %%
def validateRDkit(mol:str) -> bool:
    new_mol = Chem.MolFromSmiles(mol)
    if new_mol is None:
        return False
    
    return True

# %%
valdiated_smiles_yacc = [validateSMILES(row['smiles']) for _,row in df.iterrows()]
validated_smiles_rdkit = [validateRDkit(row['smiles']) for _,row in df.iterrows()]

validated_smiles_rdkit.count(False), valdiated_smiles_yacc.count(False)
# Out:
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 2
# Illegal character 'n' at index 3
# Illegal character 'c' at index 5
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'n' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=7, end=8)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Illegal character 'c' at index 12
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 4
# Illegal character 'c' at index 12
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=3, end=4)
# Illegal character 'c' at index 7
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 4
# Illegal character 'c' at index 6
# Illegal character 'c' at index 0
# Error on Token(type='[', value='[', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='[', value='[', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'n' at index 1
# Illegal character 'n' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 12
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=8, end=9)
# Illegal character 'c' at index 1
# Error on Token(type='[', value='[', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Illegal character 'n' at index 1
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=7, end=8)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 6
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 6
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=11, end=12)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 6
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=7, end=8)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=12, end=13)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 5
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=7, end=8)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=11, end=12)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 11
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Illegal character 'n' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=4, end=5)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'n' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 6
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=8, end=9)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 4
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=7, end=8)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=17, end=18)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Illegal character 'c' at index 10
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=2, end=3)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=7, end=8)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=4, end=5)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=3, end=4)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 7
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=8, end=9)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=3, end=4)
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 7
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=3, end=4)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 0
# Illegal character 'c' at index 12
# Illegal character 'c' at index 11
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=8, end=9)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=6, end=7)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 5
# Illegal character 'c' at index 0
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=12, end=13)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Illegal character 'c' at index 12
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=9, end=10)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'n' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=12, end=13)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=10, end=11)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=7, end=8)
# Illegal character 'c' at index 10
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=17, end=18)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 15
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=3, end=4)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'n' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 4
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# ...
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=12, end=13)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=4, end=5)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=8, end=9)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 10
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 6
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=6, end=7)
# Illegal character 'n' at index 4
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Illegal character 'c' at index 0
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Illegal character 'n' at index 1
# Illegal character 'c' at index 0
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='[', value='[', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'n' at index 3
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='S', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='[', value='[', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=10, end=11)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=3, end=4)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 12
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=4, end=5)
# Illegal character 'c' at index 4
# Illegal character 'c' at index 7
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='[', value='[', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=2, end=3)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=4, end=5)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=4, end=5)
# Error on Token(type='[', value='[', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='O', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=6, end=7)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Illegal character 'c' at index 1
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# Error on Token(type='semi_organic_symbol', value='N', lineno=1, index=4, end=5)
# (0, 4336)

# %%
smiles = [row['smiles'] for _, row in df.iterrows()]
validateSMILES("NC"), smiles[19]
# Out:
# Error on Token(type='semi_organic_symbol', value='C', lineno=1, index=1, end=2)
# (False, 'NCCNCCNCCN')
