# %%
from yacc import validateSMILES
import pandas as pd
from rdkit import Chem
# Out:
# WARNING: 20 shift/reduce conflicts
# Parser debugging for SmilesParser written to parser.out
# True

# %%
file_path = 'data/mutagenicity.csv'

# %%
df = pd.read_csv(file_path, index_col=0)
df
# Out:
#       mut                                             smiles
# 0     1.0      COc1ccc(-c2nc(-c3ccccc3)c(-c3ccccc3)[nH]2)cc1
# 1     1.0                              Cc1c(N=C=O)cccc1N=C=O
# 2     0.0           CC1(Cn2ccnn2)C(C(=O)O)N2C(=O)CC2S1(=O)=O
# 3     0.0                                   C=CC(=O)OCCN(C)C
# 4     0.0                               Clc1cc(Cl)c(Cl)cc1Cl
# ...   ...                                                ...
# 4332  1.0  CCCn1cc2c3c(cccc31)C1C=C(C)CN(C)C1C2.O=C(O)C(O...
# 4333  0.0                 CCCCCCCCCCCCOCCOCCOCCOCCOCCOCCOCCO
# 4334  0.0                    Nc1ccn(C2C=C(CO)C(O)C2O)c(=O)n1
# 4335  1.0                                         CCC(C)ON=O
# 4336  0.0                   O=C1NC(=S)NC(=O)C1C(=O)Nc1ccccc1
#
# [4337 rows x 2 columns]

# %%
def validateRDkit(mol:str) -> bool:
    new_mol = Chem.MolFromSmiles(mol)
    if new_mol is None:
        return False
    
    return True

# %%
valdiated_smiles_yacc = [validateSMILES(row['smiles']) for _,row in df.iterrows()]
validated_smiles_rdkit = [validateRDkit(row['smiles']) for _,row in df.iterrows()]

validated_smiles_rdkit.count(False), valdiated_smiles_yacc.count(False)
# Out:
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'n' at index 5
# Illegal character 'c' at index 2
# Illegal character 'n' at index 3
# Illegal character 'c' at index 5
# Illegal character 'c' at index 10
# Illegal character 'c' at index 7
# Illegal character 'n' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 11
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 11
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# Illegal character 'c' at index 16
# Illegal character 'c' at index 18
# Illegal character 'c' at index 29
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 4
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 13
# Illegal character 'c' at index 5
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Illegal character 'c' at index 17
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# Illegal character 'c' at index 8
# Illegal character 'c' at index 18
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 3
# Illegal character 'c' at index 4
# Illegal character 'c' at index 4
# Illegal character 'c' at index 6
# Illegal character 'c' at index 0
# Illegal character 'n' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'a' at index 25
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'n' at index 1
# Illegal character 'n' at index 1
# Illegal character 'c' at index 50
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 16
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 19
# Illegal character 'c' at index 1
# Illegal character 'c' at index 14
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 14
# Illegal character 'c' at index 11
# Illegal character 'c' at index 9
# Illegal character 'c' at index 11
# Illegal character 'c' at index 14
# Illegal character 'c' at index 11
# Illegal character 'c' at index 1
# Illegal character 'n' at index 2
# Illegal character 'c' at index 18
# Illegal character 'c' at index 3
# Illegal character 'c' at index 16
# Illegal character 'c' at index 0
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Illegal character 'n' at index 8
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 19
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# Illegal character 'c' at index 7
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 4
# Illegal character 'c' at index 13
# Illegal character 'n' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 14
# Illegal character 'c' at index 12
# Illegal character 'c' at index 4
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 9
# Illegal character 'c' at index 6
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'a' at index 18
# Illegal character 'c' at index 0
# Illegal character 'c' at index 18
# Illegal character 'c' at index 11
# Illegal character 'c' at index 5
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 4
# Illegal character 'c' at index 15
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 25
# Illegal character 'c' at index 8
# Illegal character 'c' at index 9
# Illegal character 'c' at index 6
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 11
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 33
# Illegal character 'c' at index 14
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 19
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 12
# Illegal character 'c' at index 13
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'a' at index 11
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 11
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 11
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 9
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 4
# Illegal character 'c' at index 6
# Illegal character 'c' at index 5
# Illegal character 'c' at index 0
# Illegal character 'n' at index 1
# Illegal character 'c' at index 8
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'n' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 7
# Illegal character 'n' at index 3
# Illegal character 'n' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 6
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 0
# Illegal character 'c' at index 4
# Illegal character 'c' at index 17
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 19
# Illegal character 'n' at index 10
# Illegal character 'c' at index 4
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 14
# Illegal character 'c' at index 16
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# Illegal character 'c' at index 6
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 3
# Illegal character 'c' at index 10
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 35
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 9
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 8
# Illegal character 'n' at index 15
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 8
# Illegal character 'c' at index 15
# Illegal character 'c' at index 10
# Illegal character 'c' at index 0
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 15
# Illegal character 'c' at index 9
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 21
# Illegal character 'c' at index 11
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 0
# Illegal character 'c' at index 69
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 8
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 16
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 13
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 25
# Illegal character 'c' at index 5
# Illegal character 'n' at index 13
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'a' at index 23
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 7
# Illegal character 'c' at index 6
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 13
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 14
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'a' at index 29
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 5
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 11
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 8
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 9
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 5
# Illegal character 'n' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 18
# Illegal character 'c' at index 4
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 8
# Illegal character 'c' at index 12
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 20
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 11
# Illegal character 'c' at index 10
# Illegal character 'c' at index 11
# Illegal character 'c' at index 1
# Illegal character 'c' at index 14
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 15
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 5
# Illegal character 'n' at index 12
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# Illegal character 'c' at index 4
# Illegal character 'c' at index 11
# Illegal character 'c' at index 32
# Illegal character 'c' at index 5
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# Illegal character 'c' at index 4
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'n' at index 1
# Illegal character 'c' at index 10
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 14
# Illegal character 'c' at index 9
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 8
# Illegal character 'c' at index 9
# Illegal character 'c' at index 3
# Illegal character 'c' at index 4
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'n' at index 2
# Illegal character 'c' at index 21
# Illegal character 'c' at index 8
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 0
# Illegal character 'c' at index 7
# Illegal character 'c' at index 10
# Illegal character 'c' at index 6
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 6
# Illegal character 'c' at index 3
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'n' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 8
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 27
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 4
# Illegal character 'c' at index 10
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 4
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 17
# Illegal character 'c' at index 7
# Illegal character 'c' at index 3
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# Illegal character 'c' at index 13
# Illegal character 'c' at index 21
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 7
# Illegal character 'n' at index 2
# Illegal character 'c' at index 6
# Illegal character 'c' at index 12
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 41
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 5
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 13
# Illegal character 'c' at index 6
# Illegal character 'c' at index 12
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 7
# Illegal character 'c' at index 0
# Illegal character 'c' at index 14
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 25
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# Illegal character 'n' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 14
# Illegal character 'c' at index 8
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 11
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 11
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 6
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# Illegal character 'c' at index 9
# Illegal character 'c' at index 10
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 10
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 5
# Illegal character 'c' at index 4
# Illegal character 'c' at index 6
# Illegal character 'c' at index 4
# Illegal character 'c' at index 3
# Illegal character 'c' at index 5
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 18
# Illegal character 'c' at index 10
# Illegal character 'c' at index 0
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# Illegal character 'c' at index 6
# Illegal character 'c' at index 6
# Illegal character 'c' at index 8
# Illegal character 'c' at index 14
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 3
# Illegal character 'c' at index 4
# Illegal character 'c' at index 4
# Illegal character 'c' at index 8
# Illegal character 'c' at index 2
# Illegal character 'c' at index 12
# Illegal character 'c' at index 2
# Illegal character 'c' at index 14
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 15
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 15
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'a' at index 17
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 5
# Illegal character 'c' at index 2
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# Illegal character 'c' at index 4
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 28
# Illegal character 'c' at index 32
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 9
# Illegal character 'c' at index 16
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 2
# Illegal character 'c' at index 17
# Illegal character 'c' at index 8
# Illegal character 'c' at index 4
# Illegal character 'c' at index 16
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 20
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 10
# Illegal character 'c' at index 9
# Illegal character 'c' at index 0
# Illegal character 'c' at index 6
# Illegal character 'c' at index 9
# Illegal character 'c' at index 15
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 13
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 25
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 16
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'n' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 13
# Illegal character 'c' at index 3
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 25
# Illegal character 'c' at index 7
# Illegal character 'c' at index 19
# Illegal character 'c' at index 3
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 10
# Illegal character 'c' at index 18
# Illegal character 'c' at index 6
# Illegal character 'c' at index 4
# Illegal character 'c' at index 8
# Illegal character 'c' at index 10
# Illegal character 'c' at index 6
# Illegal character 'c' at index 11
# Illegal character 'c' at index 10
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 14
# Illegal character 'c' at index 10
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 14
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 6
# Illegal character 'c' at index 3
# Illegal character 'c' at index 6
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 19
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'n' at index 2
# Illegal character 'c' at index 5
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 12
# Illegal character 'c' at index 14
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 12
# Illegal character 'c' at index 23
# Illegal character 'c' at index 14
# Illegal character 'c' at index 11
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 7
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'n' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'a' at index 41
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 5
# Illegal character 'c' at index 16
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 30
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 16
# Illegal character 'c' at index 9
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 10
# Illegal character 'c' at index 9
# Illegal character 'c' at index 5
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 5
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'n' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 10
# Illegal character 'c' at index 0
# Illegal character 'c' at index 9
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 4
# Illegal character 'c' at index 5
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 51
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 8
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 21
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'a' at index 27
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 7
# Illegal character 'c' at index 20
# Illegal character 'c' at index 14
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 3
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 14
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'n' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 4
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 12
# Illegal character 'c' at index 39
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'n' at index 2
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'n' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 4
# Illegal character 'c' at index 7
# Illegal character 'c' at index 3
# Illegal character 'c' at index 6
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 11
# Illegal character 'n' at index 8
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 20
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 11
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 10
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 11
# Illegal character 'c' at index 0
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 4
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 20
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 16
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 13
# Illegal character 'c' at index 7
# Illegal character 'c' at index 5
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 11
# Illegal character 'c' at index 6
# Illegal character 'c' at index 0
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 6
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'a' at index 17
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 7
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 13
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# Illegal character 'c' at index 9
# Illegal character 'c' at index 4
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 16
# Illegal character 'c' at index 0
# Illegal character 'c' at index 8
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 10
# Illegal character 'c' at index 7
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 20
# Illegal character 'c' at index 5
# Illegal character 'c' at index 3
# Illegal character 'c' at index 8
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# ...
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 9
# Illegal character 'c' at index 5
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 13
# Illegal character 'c' at index 2
# Illegal character 'c' at index 23
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'n' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 7
# Illegal character 'n' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'n' at index 2
# Illegal character 'c' at index 31
# Illegal character 'c' at index 4
# Illegal character 'c' at index 3
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 11
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'n' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 8
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 8
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 9
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 5
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 3
# Illegal character 'c' at index 8
# Illegal character 'c' at index 7
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 0
# Illegal character 'n' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 3
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 13
# Illegal character 'c' at index 98
# Illegal character 'c' at index 2
# Illegal character 'c' at index 10
# Illegal character 'c' at index 6
# Illegal character 'c' at index 50
# Illegal character 'c' at index 0
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 15
# Illegal character 'c' at index 6
# Illegal character 'a' at index 32
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 13
# Illegal character 'c' at index 2
# Illegal character 'c' at index 8
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 16
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 8
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 16
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'n' at index 3
# Error on Token(type='H', value='H', lineno=1, index=4, end=5), last rule organic_symbol
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 14
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 10
# Illegal character 'c' at index 9
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 12
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 5
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# Illegal character 'c' at index 15
# Illegal character 'c' at index 3
# Illegal character 'c' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'n' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 16
# Illegal character 'c' at index 2
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 17
# Illegal character 'c' at index 1
# Illegal character 'c' at index 14
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 13
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 6
# Illegal character 'c' at index 2
# Illegal character 'c' at index 8
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 14
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 8
# Illegal character 'c' at index 2
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 16
# Illegal character 'n' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 22
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 15
# Illegal character 'c' at index 2
# Illegal character 'c' at index 14
# Illegal character 'c' at index 4
# Illegal character 'c' at index 13
# Illegal character 'c' at index 1
# Illegal character 'c' at index 1
# Illegal character 'c' at index 7
# Illegal character 'c' at index 14
# Illegal character 'n' at index 17
# Illegal character 'c' at index 4
# Illegal character 'c' at index 10
# Illegal character 'c' at index 14
# No symbol isotope. Must be one of {symbol, charge}.
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 9
# Illegal character 'c' at index 10
# Illegal character 'c' at index 11
# Illegal character 'a' at index 39
# Illegal character 'c' at index 6
# Illegal character 'c' at index 4
# Illegal character 'a' at index 21
# Illegal character 'c' at index 15
# Illegal character 'a' at index 10
# Illegal character 'n' at index 4
# Illegal character 'c' at index 2
# Illegal character 'c' at index 17
# Illegal character 'a' at index 26
# Illegal character 'c' at index 7
# Illegal character 'c' at index 0
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 12
# Illegal character 'c' at index 15
# Illegal character 'n' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 2
# Illegal character 'c' at index 43
# Illegal character 'c' at index 15
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 5
# Illegal character 'c' at index 2
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'n' at index 3
# Illegal character 'c' at index 11
# Illegal character 'c' at index 9
# Illegal character 'c' at index 2
# Illegal character 'n' at index 15
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 6
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 49
# Illegal character 'c' at index 11
# Illegal character 'c' at index 12
# Illegal character 'c' at index 2
# Illegal character 'n' at index 7
# Illegal character 'c' at index 6
# Illegal character 'c' at index 9
# Illegal character 'c' at index 1
# Illegal character 'c' at index 35
# Illegal character 'c' at index 1
# Illegal character 'c' at index 9
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 10
# Illegal character 'c' at index 38
# Illegal character 'c' at index 13
# Illegal character 'c' at index 13
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 24
# Illegal character 'c' at index 3
# Illegal character 'c' at index 2
# Illegal character 'c' at index 11
# Illegal character 'c' at index 2
# Illegal character 'c' at index 13
# Illegal character 'c' at index 15
# Illegal character 'c' at index 8
# Illegal character 'c' at index 4
# Illegal character 'c' at index 7
# Illegal character 'a' at index 30
# Illegal character 'n' at index 2
# Illegal character 'c' at index 6
# Illegal character 'c' at index 1
# Illegal character 'c' at index 25
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'c' at index 6
# Illegal character 'c' at index 8
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'c' at index 1
# Illegal character 'c' at index 5
# Illegal character 'c' at index 1
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 17
# Illegal character 'c' at index 7
# Illegal character 'c' at index 7
# Illegal character 'c' at index 2
# Illegal character 'n' at index 2
# Illegal character 'c' at index 2
# Illegal character 'a' at index 39
# Illegal character 'c' at index 4
# Illegal character 'c' at index 7
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'c' at index 2
# Illegal character 'c' at index 58
# Illegal character 'c' at index 7
# Illegal character 'c' at index 43
# Illegal character 'c' at index 2
# Illegal character 'c' at index 1
# Illegal character 'a' at index 20
# Illegal character 'c' at index 22
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'c' at index 1
# Illegal character 'c' at index 33
# Illegal character 'c' at index 1
# Illegal character 'c' at index 0
# Illegal character 'c' at index 4
# Illegal character 'c' at index 67
# Illegal character 'c' at index 1
# Illegal character 'c' at index 2
# Illegal character 'a' at index 14
# Illegal character 'c' at index 1
# Illegal character 'c' at index 4
# Illegal character 'n' at index 2
# Illegal character 'c' at index 2
# No symbol isotope. Must be one of {symbol, charge}.
# Illegal character 'n' at index 3
# Illegal character 'c' at index 1
# Illegal character 'c' at index 24
# (0, 3284)

# %%
smiles = [row['smiles'] for _, row in df.iterrows()]
validateSMILES("NC"), smiles[19], len(smiles)
# Out:
# (True, 'NCCNCCNCCN', 4337)
