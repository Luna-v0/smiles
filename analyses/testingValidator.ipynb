# %%
from src.chem import chemistry
import pandas as pd
from rdkit import Chem

# %%
file_path = 'data/mutagenicity.csv'

# %%
df = pd.read_csv(file_path, index_col=0)
df
# Out:
# :

# %%
def validateRDkit(mol:str) -> bool:
    new_mol = Chem.MolFromSmiles(mol)
    if new_mol is None:
        return False
    
    return True

# %%
from src import validate_smiles

valdiated_smiles_yacc = [validate_smiles(row['smiles'])[0] for _,row in df.iterrows()]
validated_smiles_rdkit = [validateRDkit(row['smiles']) for _,row in df.iterrows()]

validated_smiles_rdkit.count(False), valdiated_smiles_yacc.count(False)

# %%
[row['smiles'] for _,row in df.iterrows() if not validate_smiles(row['smiles'])[0]]

# %%
df = pd.read_csv('data/tox21.csv', compression='gzip')
df['smiles']
